# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # eda

# %%
# The dataset directory that we used is located inside a shared Google Drive folder
# You may need to change the data source directory accordingly

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/BT4240 Repo/data.csv', delimiter = ';')

# %%
df.tail(5)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4419                           125.0            1                       1
# 4420                           120.0          105                       1
# 4421                           154.0            1                      37
# 4422                           180.0            1                      37
# 4423                           152.0           22                      38
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 4419                       1  ...                                    0
# 4420                       1  ...                                    0
# 4421                      37  ...                                    0
# 4422                      37  ...                                    0
# 4423                      37  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 4419                                    6
# 4420                                    6
# 4421                                    8
# 4422                                    5
# 4423                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 4419                                       8
# 4420                                       6
# 4421                                       9
# 4422                                       6
# 4423                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 4419                                    5                         12.666667
# 4420                                    2                         11.000000
# 4421                                    1                         13.500000
# 4422                                    5                         12.000000
# 4423                                    6                         13.000000
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 4419                                               0               15.5
# 4420                                               0               11.1
# 4421                                               0               13.9
# 4422                                               0                9.4
# 4423                                               0               12.7
#
#       Inflation rate   GDP    Target
# 4419             2.8 -4.06  Graduate
# 4420             0.6  2.02   Dropout
# 4421            -0.3  0.79   Dropout
# 4422            -0.8 -3.12  Graduate
# 4423             3.7 -1.70  Graduate
#
# [5 rows x 37 columns]

# %%
df.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance\t                        int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# Tuition fees up to date                             int64
# Gender                                              int64
# Scholarship holder                                  int64
# Age at enrollment                                   int64
# International                                       int64
# Curricular units 1st sem (credited)                 int64
# Curricular units 1st sem (enrolled)                 int64
# Curricular units 1st sem (evaluations)              int64
# Curricular units 1st sem (approved)                 int64
# Curricular units 1st sem (grade)                  float64
# Curricular units 1st sem (without evaluations)      int64
# Curricular units 2nd sem (credited)                 int64
# Curricular units 2nd sem (enrolled)                 int64
# Curricular units 2nd sem (evaluations)              int64
# Curricular units 2nd sem (approved)                 int64
# Curricular units 2nd sem (grade)                  float64
# Curricular units 2nd sem (without evaluations)      int64
# Unemployment rate                                 float64
# Inflation rate                                    float64
# GDP                                               float64
# Target                                             object
# dtype: object

# %%
df.shape
# Out:
# (4424, 37)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()[1].sum()
# Out:
# <ipython-input-17-643ff1c319a2>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.isnull().sum()[1].sum()
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
#        'Inflation rate', 'GDP', 'Target'],
#       dtype='object')

# %%
numerical_vars = [
    "Application order", "Previous qualification (grade)", "Admission grade", "Age at enrollment",
    "Curricular units 1st sem (credited)", "Curricular units 1st sem (enrolled)",
    "Curricular units 1st sem (evaluations)", "Curricular units 1st sem (approved)",
    "Curricular units 1st sem (grade)", "Curricular units 1st sem (without evaluations)",
    "Curricular units 2nd sem (credited)", "Curricular units 2nd sem (enrolled)",
    "Curricular units 2nd sem (evaluations)", "Curricular units 2nd sem (approved)",
    "Curricular units 2nd sem (grade)", "Curricular units 2nd sem (without evaluations)",
    "Unemployment rate", "Inflation rate", "GDP"
]

df[numerical_vars].describe()
# Out:
#        Application order  Previous qualification (grade)  Admission grade  \
# count        4424.000000                     4424.000000      4424.000000
# mean            1.727848                      132.613314       126.978119
# std             1.313793                       13.188332        14.482001
# min             0.000000                       95.000000        95.000000
# 25%             1.000000                      125.000000       117.900000
# 50%             1.000000                      133.100000       126.100000
# 75%             2.000000                      140.000000       134.800000
# max             9.000000                      190.000000       190.000000
#
#        Age at enrollment  Curricular units 1st sem (credited)  \
# count        4424.000000                          4424.000000
# mean           23.265145                             0.709991
# std             7.587816                             2.360507
# min            17.000000                             0.000000
# 25%            19.000000                             0.000000
# 50%            20.000000                             0.000000
# 75%            25.000000                             0.000000
# max            70.000000                            20.000000
#
#        Curricular units 1st sem (enrolled)  \
# count                          4424.000000
# mean                              6.270570
# std                               2.480178
# min                               0.000000
# 25%                               5.000000
# 50%                               6.000000
# 75%                               7.000000
# max                              26.000000
#
#        Curricular units 1st sem (evaluations)  \
# count                             4424.000000
# mean                                 8.299051
# std                                  4.179106
# min                                  0.000000
# 25%                                  6.000000
# 50%                                  8.000000
# 75%                                 10.000000
# max                                 45.000000
#
#        Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# count                          4424.000000                       4424.000000
# mean                              4.706600                         10.640822
# std                               3.094238                          4.843663
# min                               0.000000                          0.000000
# 25%                               3.000000                         11.000000
# 50%                               5.000000                         12.285714
# 75%                               6.000000                         13.400000
# max                              26.000000                         18.875000
#
#        Curricular units 1st sem (without evaluations)  \
# count                                     4424.000000
# mean                                         0.137658
# std                                          0.690880
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                         12.000000
#
#        Curricular units 2nd sem (credited)  \
# count                          4424.000000
# mean                              0.541817
# std                               1.918546
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              19.000000
#
#        Curricular units 2nd sem (enrolled)  \
# count                          4424.000000
# mean                              6.232143
# std                               2.195951
# min                               0.000000
# 25%                               5.000000
# 50%                               6.000000
# 75%                               7.000000
# max                              23.000000
#
#        Curricular units 2nd sem (evaluations)  \
# count                             4424.000000
# mean                                 8.063291
# std                                  3.947951
# min                                  0.000000
# 25%                                  6.000000
# 50%                                  8.000000
# 75%                                 10.000000
# max                                 33.000000
#
#        Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# count                          4424.000000                       4424.000000
# mean                              4.435805                         10.230206
# std                               3.014764                          5.210808
# min                               0.000000                          0.000000
# 25%                               2.000000                         10.750000
# 50%                               5.000000                         12.200000
# 75%                               6.000000                         13.333333
# max                              20.000000                         18.571429
#
#        Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# count                                     4424.000000        4424.000000
# mean                                         0.150316          11.566139
# std                                          0.753774           2.663850
# min                                          0.000000           7.600000
# 25%                                          0.000000           9.400000
# 50%                                          0.000000          11.100000
# 75%                                          0.000000          13.900000
# max                                         12.000000          16.200000
#
#        Inflation rate          GDP
# count     4424.000000  4424.000000
# mean         1.228029     0.001969
# std          1.382711     2.269935
# min         -0.800000    -4.060000
# 25%          0.300000    -1.700000
# 50%          1.400000     0.320000
# 75%          2.600000     1.790000
# max          3.700000     3.510000

# %%
df['Mother\'s occupation'].value_counts()
# Out:
# Mother's occupation
# 9      1577
# 4       817
# 5       530
# 3       351
# 2       318
# 7       272
# 0       144
# 1       102
# 6        91
# 90       70
# 8        36
# 191      26
# 99       17
# 194      11
# 141       8
# 123       7
# 144       6
# 175       5
# 192       5
# 10        4
# 134       4
# 193       4
# 151       3
# 132       3
# 143       3
# 153       2
# 152       2
# 122       2
# 125       1
# 173       1
# 131       1
# 171       1
# Name: count, dtype: int64

# %%
df['Father\'s occupation'].value_counts()
# Out:
# Father's occupation
# 9      1010
# 7       666
# 5       516
# 4       386
# 3       384
# 8       318
# 10      266
# 6       242
# 2       197
# 1       134
# 0       128
# 90       65
# 99       19
# 193      15
# 144       8
# 171       8
# 192       6
# 163       5
# 103       4
# 175       4
# 181       3
# 135       3
# 152       3
# 183       3
# 123       3
# 112       2
# 194       2
# 182       2
# 172       2
# 151       2
# 102       2
# 122       2
# 124       1
# 131       1
# 195       1
# 121       1
# 132       1
# 161       1
# 143       1
# 134       1
# 153       1
# 174       1
# 141       1
# 114       1
# 101       1
# 154       1
# Name: count, dtype: int64

# %%
df['GDP'].value_counts()
# Out:
# GDP
#  0.32    571
# -3.12    533
#  1.74    525
#  1.79    445
# -1.70    419
#  2.02    414
# -4.06    397
#  0.79    390
#  3.51    368
# -0.92    362
# Name: count, dtype: int64

# %%
df['Marital status'].value_counts()
# Out:
# Marital status
# 1    3919
# 2     379
# 4      91
# 5      25
# 6       6
# 3       4
# Name: count, dtype: int64

# %%
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces and tabs

# %%
# Manually categorize numerical and categorical variables based on their nature

# Categorical variables (even if stored as integers)
categorical_vars = [
    "Marital status", "Application mode", "Course", "Daytime/evening attendance",
    "Previous qualification", "Nacionality", "Mother's qualification", "Father's qualification",
    "Mother's occupation", "Father's occupation", "Displaced", "Educational special needs",
    "Debtor", "Tuition fees up to date", "Gender", "Scholarship holder", "International", "Target"
]

# Numerical variables (continuous or ordinal in nature)
numerical_vars = [
    "Application order", "Previous qualification (grade)", "Admission grade", "Age at enrollment",
    "Curricular units 1st sem (credited)", "Curricular units 1st sem (enrolled)",
    "Curricular units 1st sem (evaluations)", "Curricular units 1st sem (approved)",
    "Curricular units 1st sem (grade)", "Curricular units 1st sem (without evaluations)",
    "Curricular units 2nd sem (credited)", "Curricular units 2nd sem (enrolled)",
    "Curricular units 2nd sem (evaluations)", "Curricular units 2nd sem (approved)",
    "Curricular units 2nd sem (grade)", "Curricular units 2nd sem (without evaluations)",
    "Unemployment rate", "Inflation rate", "GDP"
]

import math

# Combine numerical and categorical variables for plotting
all_vars = numerical_vars + categorical_vars

# Determine number of rows needed for an n x 3 layout
cols = 3  # Number of columns
rows = math.ceil(len(all_vars) / cols)  # Determine the number of rows needed

# Create a single figure with an n x 3 layout
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(18, 5 * rows))
axes = axes.flatten()  # Flatten the axes array for easy iteration

# Plot histograms for numerical variables
for i, col in enumerate(numerical_vars):
    sns.histplot(df[col], kde=True, bins=30, ax=axes[i])
    axes[i].set_title(f"Histogram of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Frequency")

# Plot bar plots for categorical variables
for j, col in enumerate(categorical_vars, start=len(numerical_vars)):
    sns.countplot(x=df[col], ax=axes[j])
    axes[j].set_title(f"Bar plot of {col}")
    axes[j].set_xlabel(col)
    axes[j].set_ylabel("Count")
    axes[j].tick_params(axis='x', rotation=45)

# Remove any unused subplots (in case of an uneven number of plots)
for k in range(len(all_vars), len(axes)):
    fig.delaxes(axes[k])

# Adjust layout and display the figure
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Combine 'Graduate' and 'Enrolled' into a single class 'Not Dropout'
df["Target"] = df["Target"].replace({"Graduate": "Not Dropout", "Enrolled": "Not Dropout"})

# Convert "Target" and categorical variables to categorical type
df["Target"] = df["Target"].astype(str)
df[categorical_vars] = df[categorical_vars].astype(str)  # Ensure categorical vars are strings

# Selected meaningful numerical variables for bivariate analysis
selected_vars = [
    "Admission grade", "Age at enrollment", "Scholarship holder",
    "Curricular units 1st sem (grade)", "Curricular units 2nd sem (grade)",
    "Previous qualification (grade)", "Unemployment rate", "Inflation rate", "GDP"
]

# Determine the number of rows needed
cols = 3  # Number of columns
total_plots = len(selected_vars) + len(categorical_vars)  # Total subplots needed
rows = math.ceil(total_plots / cols)  # Calculate required rows

# Create figure with an n x 3 layout
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(18, 5 * rows))
axes = axes.flatten()  # Flatten the axes array for iteration

# Plot boxplots for numerical variables
for i, col in enumerate(selected_vars):
    sns.boxplot(x=df["Target"], y=df[col], ax=axes[i])
    axes[i].set_title(f"Boxplot of {col} by Target")
    axes[i].set_xlabel("Target (Dropout(0) vs Not Dropout(1))")
    axes[i].set_ylabel(col)
    # axes[i].legend(title='Target')

# Plot bar plots for categorical variables
for j, col in enumerate(categorical_vars, start=len(selected_vars)):
    sns.countplot(x=df[col], hue=df["Target"], ax=axes[j])
    axes[j].set_title(f"Bar plot of {col} by Target")
    axes[j].set_xlabel(col)
    axes[j].set_ylabel("Count")
    axes[j].legend(title="Target")
    axes[j].tick_params(axis='x', rotation=45)

# Remove any unused subplots
for k in range(total_plots, len(axes)):
    fig.delaxes(axes[k])

# Adjust layout and display the figure
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-26-066140e557c1>:42: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[j].legend(title="Target")

# %%
plt.figure(figsize=(12, 8))
corr_matrix = df[selected_vars].corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# # Normalization

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# df1 = pd.read_csv('/content/drive/MyDrive/BT4240/data.csv')
df1 = pd.read_csv('/content/drive/MyDrive/BT4240 Repo/data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1.head()
# Out:
#   Marital status;Application mode;Application order;Course;"Daytime/evening attendance\t";Previous qualification;Previous qualification (grade);Nacionality;Mother's qualification;Father's qualification;Mother's occupation;Father's occupation;Admission grade;Displaced;Educational special needs;Debtor;Tuition fees up to date;Gender;Scholarship holder;Age at enrollment;International;Curricular units 1st sem (credited);Curricular units 1st sem (enrolled);Curricular units 1st sem (evaluations);Curricular units 1st sem (approved);Curricular units 1st sem (grade);Curricular units 1st sem (without evaluations);Curricular units 2nd sem (credited);Curricular units 2nd sem (enrolled);Curricular units 2nd sem (evaluations);Curricular units 2nd sem (approved);Curricular units 2nd sem (grade);Curricular units 2nd sem (without evaluations);Unemployment rate;Inflation rate;GDP;Target
# 0  1;17;5;171;1;1;122.0;1;19;12;5;9;127.3;1;0;0;1...
# 1  1;15;1;9254;1;1;160.0;1;1;3;3;3;142.5;1;0;0;0;...
# 2  1;1;5;9070;1;1;122.0;1;37;37;9;9;124.8;1;0;0;0...
# 3  1;17;2;9773;1;1;122.0;1;38;37;5;3;119.6;1;0;0;...
# 4  2;39;1;8014;0;1;100.0;1;37;38;9;9;141.5;0;0;0;...

# %%
df1.describe()
# Out:
#        Marital status;Application mode;Application order;Course;"Daytime/evening attendance\t";Previous qualification;Previous qualification (grade);Nacionality;Mother's qualification;Father's qualification;Mother's occupation;Father's occupation;Admission grade;Displaced;Educational special needs;Debtor;Tuition fees up to date;Gender;Scholarship holder;Age at enrollment;International;Curricular units 1st sem (credited);Curricular units 1st sem (enrolled);Curricular units 1st sem (evaluations);Curricular units 1st sem (approved);Curricular units 1st sem (grade);Curricular units 1st sem (without evaluations);Curricular units 2nd sem (credited);Curricular units 2nd sem (enrolled);Curricular units 2nd sem (evaluations);Curricular units 2nd sem (approved);Curricular units 2nd sem (grade);Curricular units 2nd sem (without evaluations);Unemployment rate;Inflation rate;GDP;Target
# count                                                4424
# unique                                               4424
# top     1;10;1;9773;1;1;152.0;22;38;37;5;9;152.0;1;0;0...
# freq                                                    1

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# df1 = pd.read_csv('/content/drive/MyDrive/BT4240/data.csv', delimiter=';')
df1 = pd.read_csv('/content/drive/MyDrive/BT4240 Repo/data.csv', delimiter=';')
df1.columns = df1.columns.str.strip()

min_max_cols = [
    "Previous qualification (grade)", "Admission grade", "Age at enrollment",
    "Unemployment rate",
    "Curricular units 1st sem (credited)", "Curricular units 1st sem (enrolled)",
    "Curricular units 1st sem (evaluations)", "Curricular units 1st sem (approved)",
    "Curricular units 1st sem (grade)", "Curricular units 1st sem (without evaluations)",
    "Curricular units 2nd sem (credited)", "Curricular units 2nd sem (enrolled)",
    "Curricular units 2nd sem (evaluations)", "Curricular units 2nd sem (approved)",
    "Curricular units 2nd sem (grade)", "Curricular units 2nd sem (without evaluations)",
    "Inflation rate", "GDP"
]

#z_score_cols = [
    #"Inflation rate", "GDP"
#]

# Create and apply scalers
scaler_minmax = MinMaxScaler()
df1[min_max_cols] = scaler_minmax.fit_transform(df1[min_max_cols])

#scaler_zscore = StandardScaler()
#df1[z_score_cols] = scaler_zscore.fit_transform(df1[z_score_cols])

# Save the normalized data
df1.to_csv("normalized_data.csv", index=False)
print(df1.head())
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                        0.284211            1                      19
# 1                        0.684211            1                       1
# 2                        0.284211            1                      37
# 3                        0.284211            1                      38
# 4                        0.052632            1                      37
#
#    Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                      12  ...                                  0.0
# 1                       3  ...                                  0.0
# 2                      37  ...                                  0.0
# 3                      37  ...                                  0.0
# 4                      38  ...                                  0.0
#
#    Curricular units 2nd sem (enrolled)  \
# 0                              0.00000
# 1                              0.26087
# 2                              0.26087
# 3                              0.26087
# 4                              0.26087
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                0.000000
# 1                                0.181818
# 2                                0.000000
# 3                                0.303030
# 4                                0.181818
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                 0.00                          0.000000
# 1                                 0.30                          0.735897
# 2                                 0.00                          0.000000
# 3                                 0.25                          0.667692
# 4                                 0.30                          0.700000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                             0.0           0.372093
# 1                                             0.0           0.732558
# 2                                             0.0           0.372093
# 3                                             0.0           0.209302
# 4                                             0.0           0.732558
#
#    Inflation rate       GDP    Target
# 0        0.488889  0.766182   Dropout
# 1        0.111111  0.640687  Graduate
# 2        0.488889  0.766182   Dropout
# 3        0.000000  0.124174  Graduate
# 4        0.111111  0.640687  Graduate
#
# [5 rows x 37 columns]

# %% [markdown]
# #Transformation

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
# Load the dataset
# df = pd.read_csv('/content/drive/MyDrive/data.csv', delimiter=';')
df = pd.read_csv('/content/drive/MyDrive/BT4240 Repo/data.csv', delimiter=';')
# List of categorical variables
categorical_vars = [
    "Marital status", "Application mode", "Course", "Daytime/evening attendance\t",
    "Previous qualification", "Nacionality", "Mother's qualification",
    "Father's qualification", "Mother's occupation", "Father's occupation",
    "Displaced", "Educational special needs", "Debtor", "Tuition fees up to date",
    "Gender", "Scholarship holder", "International"
]


# Function to apply 'others' grouping for categorical variables
def process_categorical_variable(df, column_name):
    value_counts = df[column_name].value_counts()
    if len(value_counts) > 4:
        top_categories = value_counts.head(4).index
        df[column_name] = df[column_name].apply(lambda x: x if x in top_categories else 'others')
    # If categories are less than or equal to 4, no need to group
    return df

# print("check", df["Marital status"].value_counts())
df.info()

# Apply the process to all categorical variables
for col in categorical_vars:
    df = process_categorical_variable(df, col)

# print("check again", df["Marital status"].value_counts())

# Perform One-Hot Encoding for categorical variables
# df_encoded = pd.get_dummies(df, columns=categorical_vars)

print("Before encoding:", df.columns)
df_encoded = pd.get_dummies(df, columns=categorical_vars, drop_first=True)
print("After encoding:", df_encoded.columns)

# Display the transformed dataset
print(df_encoded.head())
display(df_encoded)
print("Data transformation and one-hot encoding completed successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
#  9   Father's qualification                          4424 non-null   int64
#  10  Mother's occupation                             4424 non-null   int64
#  11  Father's occupation                             4424 non-null   int64
#  12  Admission grade                                 4424 non-null   float64
#  13  Displaced                                       4424 non-null   int64
#  14  Educational special needs                       4424 non-null   int64
#  15  Debtor                                          4424 non-null   int64
#  16  Tuition fees up to date                         4424 non-null   int64
#  17  Gender                                          4424 non-null   int64
#  18  Scholarship holder                              4424 non-null   int64
#  19  Age at enrollment                               4424 non-null   int64
#  20  International                                   4424 non-null   int64
#  21  Curricular units 1st sem (credited)             4424 non-null   int64
#  22  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  23  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  24  Curricular units 1st sem (approved)             4424 non-null   int64
#  25  Curricular units 1st sem (grade)                4424 non-null   float64
#  26  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  27  Curricular units 2nd sem (credited)             4424 non-null   int64
#  28  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  29  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  30  Curricular units 2nd sem (approved)             4424 non-null   int64
#  31  Curricular units 2nd sem (grade)                4424 non-null   float64
#  32  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  33  Unemployment rate                               4424 non-null   float64
#  34  Inflation rate                                  4424 non-null   float64
#  35  GDP                                             4424 non-null   float64
#  36  Target                                          4424 non-null   object
# dtypes: float64(7), int64(29), object(1)
# memory usage: 1.2+ MB
# Before encoding: Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
#        'Inflation rate', 'GDP', 'Target'],
#       dtype='object')
# After encoding: Index(['Application order', 'Previous qualification', 'Admission grade',
#        'Age at enrollment', 'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
#        'Inflation rate', 'GDP', 'Target', 'Marital status_1',
#        'Marital status_2', 'Marital status_4', 'Marital status_5',
#        'Marital status_others', 'Application mode_1', 'Application mode_17',
#        'Application mode_39', 'Application mode_43', 'Application mode_others',
#        'Course_9085', 'Course_9147', 'Course_9238', 'Course_9500',
#        'Course_others', 'Daytime/evening attendance\t_0',
#        'Daytime/evening attendance\t_1',
#        'Previous qualification (grade)_120.0',
#        'Previous qualification (grade)_130.0',
#        'Previous qualification (grade)_133.1',
#        'Previous qualification (grade)_140.0',
#        'Previous qualification (grade)_others', 'Nacionality_1',
#        'Nacionality_6', 'Nacionality_26', 'Nacionality_41',
#        'Nacionality_others', 'Mother's qualification_1',
#        'Mother's qualification_19', 'Mother's qualification_37',
#        'Mother's qualification_38', 'Mother's qualification_others',
#        'Father's qualification_1', 'Father's qualification_19',
#        'Father's qualification_37', 'Father's qualification_38',
#        'Father's qualification_others', 'Mother's occupation_3',
#        'Mother's occupation_4', 'Mother's occupation_5',
#        'Mother's occupation_9', 'Mother's occupation_others',
#        'Father's occupation_4', 'Father's occupation_5',
#        'Father's occupation_7', 'Father's occupation_9',
#        'Father's occupation_others', 'Displaced_0', 'Displaced_1',
#        'Educational special needs_0', 'Educational special needs_1',
#        'Debtor_0', 'Debtor_1', 'Tuition fees up to date_0',
#        'Tuition fees up to date_1', 'Gender_0', 'Gender_1',
#        'Scholarship holder_0', 'Scholarship holder_1', 'International_0',
#        'International_1'],
#       dtype='object')
#    Application order  Previous qualification  Admission grade  \
# 0                  5                       1            127.3
# 1                  1                       1            142.5
# 2                  5                       1            124.8
# 3                  2                       1            119.6
# 4                  1                       1            141.5
#
#    Age at enrollment  Curricular units 1st sem (credited)  \
# 0                 20                                    0
# 1                 19                                    0
# 2                 19                                    0
# 3                 20                                    0
# 4                 45                                    0
#
#    Curricular units 1st sem (enrolled)  \
# 0                                    0
# 1                                    6
# 2                                    6
# 3                                    6
# 4                                    6
#
#    Curricular units 1st sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                       8
# 4                                       9
#
#    Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         14.000000
# 2                                    0                          0.000000
# 3                                    6                         13.428571
# 4                                    5                         12.333333
#
#    Curricular units 1st sem (without evaluations)  ...  Debtor_0  Debtor_1  \
# 0                                               0  ...      True     False
# 1                                               0  ...      True     False
# 2                                               0  ...      True     False
# 3                                               0  ...      True     False
# 4                                               0  ...      True     False
#
#    Tuition fees up to date_0  Tuition fees up to date_1  Gender_0  Gender_1  \
# 0                      False                       True     False      True
# 1                       True                      False     False      True
# 2                       True                      False     False      True
# 3                      False                       True      True     False
# 4                      False                       True      True     False
#
#    Scholarship holder_0  Scholarship holder_1  International_0 International_1
# 0                  True                 False             True           False
# 1                  True                 False             True           False
# 2                  True                 False             True           False
# 3                  True                 False             True           False
# 4                  True                 False             True           False
#
# [5 rows x 81 columns]
#       Application order  Previous qualification  Admission grade  \
# 0                     5                       1            127.3
# 1                     1                       1            142.5
# 2                     5                       1            124.8
# 3                     2                       1            119.6
# 4                     1                       1            141.5
# ...                 ...                     ...              ...
# 4419                  6                       1            122.2
# 4420                  2                       1            119.0
# 4421                  1                       1            149.5
# 4422                  1                       1            153.8
# 4423                  1                       1            152.0
#
#       Age at enrollment  Curricular units 1st sem (credited)  \
# 0                    20                                    0
# 1                    19                                    0
# 2                    19                                    0
# 3                    20                                    0
# 4                    45                                    0
# ...                 ...                                  ...
# 4419                 19                                    0
# 4420                 18                                    0
# 4421                 30                                    0
# 4422                 20                                    0
# 4423                 22                                    0
#
#       Curricular units 1st sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       6
# 3                                       6
# 4                                       6
# ...                                   ...
# 4419                                    6
# 4420                                    6
# 4421                                    7
# 4422                                    5
# 4423                                    6
#
#       Curricular units 1st sem (evaluations)  \
# 0                                          0
# 1                                          6
# 2                                          0
# 3                                          8
# 4                                          9
# ...                                      ...
# 4419                                       7
# 4420                                       6
# 4421                                       8
# 4422                                       5
# 4423                                       8
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         14.000000
# 2                                       0                          0.000000
# 3                                       6                         13.428571
# 4                                       5                         12.333333
# ...                                   ...                               ...
# 4419                                    5                         13.600000
# 4420                                    6                         12.000000
# 4421                                    7                         14.912500
# 4422                                    5                         13.800000
# 4423                                    6                         11.666667
#
#       Curricular units 1st sem (without evaluations)  ...  Debtor_0  Debtor_1  \
# 0                                                  0  ...      True     False
# 1                                                  0  ...      True     False
# 2                                                  0  ...      True     False
# 3                                                  0  ...      True     False
# 4                                                  0  ...      True     False
# ...                                              ...  ...       ...       ...
# 4419                                               0  ...      True     False
# 4420                                               0  ...     False      True
# 4421                                               0  ...      True     False
# 4422                                               0  ...      True     False
# 4423                                               0  ...      True     False
#
#       Tuition fees up to date_0  Tuition fees up to date_1  Gender_0  \
# 0                         False                       True     False
# 1                          True                      False     False
# 2                          True                      False     False
# 3                         False                       True      True
# 4                         False                       True      True
# ...                         ...                        ...       ...
# 4419                      False                       True     False
# 4420                       True                      False      True
# 4421                      False                       True      True
# 4422                      False                       True      True
# 4423                      False                       True      True
#
#       Gender_1  Scholarship holder_0  Scholarship holder_1  International_0  \
# 0         True                  True                 False             True
# 1         True                  True                 False             True
# 2         True                  True                 False             True
# 3        False                  True                 False             True
# 4        False                  True                 False             True
# ...        ...                   ...                   ...              ...
# 4419      True                  True                 False             True
# 4420     False                  True                 False            False
# 4421     False                 False                  True             True
# 4422     False                 False                  True             True
# 4423     False                  True                 False            False
#
#      International_1
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 4419           False
# 4420            True
# 4421           False
# 4422           False
# 4423            True
#
# [4424 rows x 81 columns]
# Data transformation and one-hot encoding completed successfully!

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 81 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Application order                               4424 non-null   int64
#  1   Previous qualification                          4424 non-null   int64
#  2   Admission grade                                 4424 non-null   float64
#  3   Age at enrollment                               4424 non-null   int64
#  4   Curricular units 1st sem (credited)             4424 non-null   int64
#  5   Curricular units 1st sem (enrolled)             4424 non-null   int64
#  6   Curricular units 1st sem (evaluations)          4424 non-null   int64
#  7   Curricular units 1st sem (approved)             4424 non-null   int64
#  8   Curricular units 1st sem (grade)                4424 non-null   float64
#  9   Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  10  Curricular units 2nd sem (credited)             4424 non-null   int64
#  11  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  12  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  13  Curricular units 2nd sem (approved)             4424 non-null   int64
#  14  Curricular units 2nd sem (grade)                4424 non-null   float64
#  15  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  16  Unemployment rate                               4424 non-null   float64
#  17  Inflation rate                                  4424 non-null   float64
#  18  GDP                                             4424 non-null   float64
#  19  Target                                          4424 non-null   object
#  20  Marital status_1                                4424 non-null   bool
#  21  Marital status_2                                4424 non-null   bool
#  22  Marital status_4                                4424 non-null   bool
#  23  Marital status_5                                4424 non-null   bool
#  24  Marital status_others                           4424 non-null   bool
#  25  Application mode_1                              4424 non-null   bool
#  26  Application mode_17                             4424 non-null   bool
#  27  Application mode_39                             4424 non-null   bool
#  28  Application mode_43                             4424 non-null   bool
#  29  Application mode_others                         4424 non-null   bool
#  30  Course_9085                                     4424 non-null   bool
#  31  Course_9147                                     4424 non-null   bool
#  32  Course_9238                                     4424 non-null   bool
#  33  Course_9500                                     4424 non-null   bool
#  34  Course_others                                   4424 non-null   bool
#  35  Daytime/evening attendance	_0                   4424 non-null   bool
#  36  Daytime/evening attendance	_1                   4424 non-null   bool
#  37  Previous qualification (grade)_120.0            4424 non-null   bool
#  38  Previous qualification (grade)_130.0            4424 non-null   bool
#  39  Previous qualification (grade)_133.1            4424 non-null   bool
#  40  Previous qualification (grade)_140.0            4424 non-null   bool
#  41  Previous qualification (grade)_others           4424 non-null   bool
#  42  Nacionality_1                                   4424 non-null   bool
#  43  Nacionality_6                                   4424 non-null   bool
#  44  Nacionality_26                                  4424 non-null   bool
#  45  Nacionality_41                                  4424 non-null   bool
#  46  Nacionality_others                              4424 non-null   bool
#  47  Mother's qualification_1                        4424 non-null   bool
#  48  Mother's qualification_19                       4424 non-null   bool
#  49  Mother's qualification_37                       4424 non-null   bool
#  50  Mother's qualification_38                       4424 non-null   bool
#  51  Mother's qualification_others                   4424 non-null   bool
#  52  Father's qualification_1                        4424 non-null   bool
#  53  Father's qualification_19                       4424 non-null   bool
#  54  Father's qualification_37                       4424 non-null   bool
#  55  Father's qualification_38                       4424 non-null   bool
#  56  Father's qualification_others                   4424 non-null   bool
#  57  Mother's occupation_3                           4424 non-null   bool
#  58  Mother's occupation_4                           4424 non-null   bool
#  59  Mother's occupation_5                           4424 non-null   bool
#  60  Mother's occupation_9                           4424 non-null   bool
#  61  Mother's occupation_others                      4424 non-null   bool
#  62  Father's occupation_4                           4424 non-null   bool
#  63  Father's occupation_5                           4424 non-null   bool
#  64  Father's occupation_7                           4424 non-null   bool
#  65  Father's occupation_9                           4424 non-null   bool
#  66  Father's occupation_others                      4424 non-null   bool
#  67  Displaced_0                                     4424 non-null   bool
#  68  Displaced_1                                     4424 non-null   bool
#  69  Educational special needs_0                     4424 non-null   bool
#  70  Educational special needs_1                     4424 non-null   bool
#  71  Debtor_0                                        4424 non-null   bool
#  72  Debtor_1                                        4424 non-null   bool
#  73  Tuition fees up to date_0                       4424 non-null   bool
#  74  Tuition fees up to date_1                       4424 non-null   bool
#  75  Gender_0                                        4424 non-null   bool
#  76  Gender_1                                        4424 non-null   bool
#  77  Scholarship holder_0                            4424 non-null   bool
#  78  Scholarship holder_1                            4424 non-null   bool
#  79  International_0                                 4424 non-null   bool
#  80  International_1                                 4424 non-null   bool
# dtypes: bool(61), float64(6), int64(13), object(1)
# memory usage: 954.9+ KB
